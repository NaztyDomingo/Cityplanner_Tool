# %%
import pandas as pd

data = pd.read_csv('countyreport_emissions.csv')

data
# Out:
#                 Unnamed: 0                                        Unnamed: 1  \
# 0              Huvudsektor                                       Undersektor
# 1                     Alla                                              Alla
# 2                     Alla                                              Alla
# 3                     Alla                                              Alla
# 4                     Alla                                              Alla
# ...                    ...                                               ...
# 19340  Utrikes transporter  Utrikes flyg under 1000 m höjd i svenskt luftrum
# 19341  Utrikes transporter  Utrikes flyg under 1000 m höjd i svenskt luftrum
# 19342  Utrikes transporter  Utrikes flyg under 1000 m höjd i svenskt luftrum
# 19343  Utrikes transporter  Utrikes flyg under 1000 m höjd i svenskt luftrum
# 19344  Utrikes transporter  Utrikes flyg under 1000 m höjd i svenskt luftrum
#
# ...
