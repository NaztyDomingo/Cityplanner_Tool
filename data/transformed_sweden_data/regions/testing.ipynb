# %%
import pandas as pd

df= pd.read_csv('emission_all_regions.csv')

df
# Out:
#                       Regions  Population Electricity_and_heating Industry  \
# 0           Stockholms County   2 440 027                     337       56
# 1              Uppsala County     400 682                     502      121
# 2       Soedermanlands County     302 566                     139    5 640
# 3      Oestergoetlands County     471 912                   1 312      244
# 4         Joenkoepings County     369 113                     419      142
# 5           Kronobergs County     204 335                     240      120
# 6               Kalmar County     247 711                     404      206
# 7             Gotlands County      61 173                     279   24 724
# 8             Blekinge County     158 740                   1 241      230
# 9               Skaane County   1 414 324                     453      545
# 10            Hallands County     342 805                     489      271
# ...
